# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Import numerical computation library
import numpy as np

# Import pandas for dataset handling
import pandas as pd

# Import matplotlib for visualization
import matplotlib.pyplot as plt

# Import seaborn for advanced visualization
import seaborn as sns

# Ignore warning messages
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files

# Step 1: Upload the file
df = files.upload()
# Out:
#      <input type="file" id="files-b518ba46-7438-40f8-9f82-93d3a1bbcaf4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b518ba46-7438-40f8-9f82-93d3a1bbcaf4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Data1.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Check dataset shape
print("Dataset Shape:", df.shape)

# Display column names
print("\nColumn Names:\n", df.columns)

# Display data types
print("\nData Types:\n")
print(df.dtypes)
# Out:
# Dataset Shape: (200, 5)
#
# Column Names:
#  Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')
#
# Data Types:
#
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
kmeans = KMeans(n_clusters=5, random_state=42)
df['Cluster'] = kmeans.fit_predict(X)

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster
# 0          4
# 1          2
# 2          4
# 3          2
# 4          4
# ...

# %%
# Plot clusters
plt.figure(figsize=(8, 7))

sns.scatterplot(
    x='Annual Income (k$)',
    y='Spending Score (1-100)',
    hue='Cluster',
    palette='viridis',
    data=df,
    s=100
)

plt.title('K-Means Clustering Visualization')
plt.show()

# %%
cluster_analysis = df.groupby('Cluster').mean(numeric_only=True)
print(cluster_analysis)
# Out:
#          CustomerID        Age  Annual Income (k$)  Spending Score (1-100)
# Cluster
# 0         86.320988  42.716049           55.296296               49.518519
# 1        162.000000  32.692308           86.538462               82.128205
# 2         23.090909  25.272727           25.727273               79.363636
# 3        164.371429  41.114286           88.200000               17.114286
# 4         23.000000  45.217391           26.304348               20.913043

# %%
plt.figure(figsize=(7, 7))

sns.scatterplot(
    x='Annual Income (k$)',
    y='Spending Score (1-100)',
    hue='Cluster',
    palette='viridis',
    data=df,
    s=100
)
plt.title('K-Means Clustering Visualization')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend(title='Cluster')

plt.show()

# %% [markdown]
# **Conclusion**
#
# The K-Means model successfully divided the customers into 5 clear groups based on their income and spending habits. The results show distinct consumer profiles, such as high-income heavy spenders, high-income careful spenders, low-income shoppers, and average middle-class consumers. Instead of using the same strategy for everyone, the business can now use this specific data to launch targeted marketing campaigns that match each group's budget and lifestyle, which will help increase sales efficiently.
